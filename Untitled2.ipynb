# %% [markdown]
# <a href="https://colab.research.google.com/github/gangsan1/study1/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * <언어 AI>
# ####**자연어 처리(Natural Language Processing)**
# ------------------------------------------------------
# 알리바바는 자연어 처리를 통해 기업 사이트에 대한 제품 설명을 자동으로 생산한다고 함.
#
# 언어는 시간이 지나면서 진화하고, 격식을 갖춘 문서에서 쓰는 언어와 온라인에서 사용하는 언어가 다르다. 고전적인 방싱의 언어 처리 기법이 효과를 보려면 격식을 갖춘 언어와 온라인 신조어 관련 지식을 가지고 있어야 한다. 이는 확장성이 떨어지게 되는것이다.
# 이러한 문제를 해결하는것이 딥러닝이다.
#
# ---------------------------------------------------
# * <음성 AI>
# ####**아마존 알렉사**
# ---------------------------------------------------
#  아마존에서 개발한 인공지능 플렛폼이다. 아마존 에코를 이용하여 알렉사와 의사소통을 할 수 있며 음악재생,알림설정 등 여러가지 기능이 있다.
# 아마존은 딥러닝 기반 솔루션인 알렉사 컨버세이션을 공개함, 알렉사 컨버세이션은 딥러닝에 기반한 대화 모델링을 통해 알렉사 컨버세이션으로 복잡한 음성 경험을 구축하는 일이 쉬워졌다고 함.
#
# ---------------------------------------------------
# #<이미지 인식 AI>
# ###**구글 포토 서비스**
# ___________________________________________________
# 구글 포토는 머린러닝을 이용해서 장소 및 사물을 인식하고, 사용자가 태그를 지정하지 않아도 알아서 분류를 해놓는다. 사진에 지오태그(GPS 정보)가 없을 경우 사진을 분석하여 랜드마크를 인식하는 방법으로 사진을찍은 위치를 찾아낸다고함
#
# ---------------------------------------------------
# #<자율주행 AI>
# ###**현대기아차 부분 자율주행**
# ___________________________________________________
# 현대차·기아차가 독자 개발한 SCC-ML의 원리는 먼저 전방카메라, 레이더 등의 센서가 다양한 운전상황에서 발생되는 정보를 지속적으로 수집해 ADAS의 두뇌격인 제어컴퓨터로 보낸다. 제어컴퓨터는 입력된 정보로부터 운전자의 주행습관을 추출해 종합적인 주행성향을 파악한다. 이때 인공지능 기술 중 하나인 머신러닝 알고리즘이 적용된다.
#
# 주행성향은 크게 보면 앞차와의 거리, 가속성(얼마나 신속하게 가속하는지), 반응성(주행환경에 얼마나 민첩하게 반응하는지) 세 가지로 나눌 수 있으며 거기에 더해 다양한 속도와 주변 차량과의 거리 조건을 모두 고려했다.
#
# 완전 자율주행 자동차를 만들경우 카메라,레이더 등의 센서로 돌발 상황이 발생했을때 대처가 가능한가? 또한 센서가 고장났을때의 대처수단등이 있는가.등 여러가지를 생각해볼수 있는것 같다.
